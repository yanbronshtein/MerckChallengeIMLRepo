# %% [markdown]
# # EDA of Adult Data

# %% [markdown]
# Joel, Yaniv, Jeff<br>
# Merck Challenge - Project 2<br>
# Rutgers MSDS<br>
# 2/4/21<br>

# %% [markdown]
# Items to Check for EDA:
# 1. Data loading and checking
# 2a. Numerical summaries
# 2b. Graphical summaries
# 3. Extract important variable(s) and analyze them
# 3a. Check for outliers and missing data
# (Note: Did not include a on outliers (yet), as should determine the threshold of removing outliers first. I would suggest checking the jackknife residuals (refer to HW #6 from reg & TS))(EDIT: might be different for GLMs...)
# 3b. Develop and test simple models
# 3c. Test model assumptions
#
# Q: How much EDA should we do? (e.g. doing summaries of a few vs all variables, using some vs all of Yaniv's EDA code, etc.)

# %%
### Preliminaries
import pandas as pd # essential for data analysis
import numpy as np # gives tools for working with arrays
import matplotlib.pyplot as plt # useful for plots in general
import seaborn as sns # needed for histograms
import pylab as pyl #for generating plots: show()
import statsmodels.api as sm  #to use the Logit()
# !pip install datawig
import datawig
import collections
# Out:
# Requirement already satisfied: datawig in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (0.2.0)
# Requirement already satisfied: typing==3.6.6 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from datawig) (3.6.6)
# Requirement already satisfied: mxnet==1.4.0 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from datawig) (1.4.0)
# Requirement already satisfied: scikit-learn[alldeps]==0.22.1 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from datawig) (0.22.1)
# Requirement already satisfied: pandas==0.25.3 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from datawig) (0.25.3)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from mxnet==1.4.0->datawig) (0.8.4)
# Requirement already satisfied: requests>=2.20.0 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from mxnet==1.4.0->datawig) (2.22.0)
# Collecting numpy<1.15.0,>=1.8.2
#   Downloading numpy-1.14.6-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (24.4 MB)
#      |████████████████████████████████| 24.4 MB 500 kB/s eta 0:00:01    |███████████                     | 8.4 MB 9.1 MB/s eta 0:00:02
# Requirement already satisfied: scipy>=0.17.0 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn[alldeps]==0.22.1->datawig) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn[alldeps]==0.22.1->datawig) (0.14.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from pandas==0.25.3->datawig) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from pandas==0.25.3->datawig) (2019.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->mxnet==1.4.0->datawig) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->mxnet==1.4.0->datawig) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->mxnet==1.4.0->datawig) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->mxnet==1.4.0->datawig) (2019.11.28)
# Requirement already satisfied: six>=1.5 in /Users/yanivbronshtein/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas==0.25.3->datawig) (1.14.0)
# ERROR: numba 0.48.0 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# ERROR: astropy 4.0 has requirement numpy>=1.16, but you'll have numpy 1.14.6 which is incompatible.
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.1
#     Uninstalling numpy-1.18.1:
#       Successfully uninstalled numpy-1.18.1
# Successfully installed numpy-1.14.6

# %%
# Loading and Checking Data

  # type and enter pwd and see if dataset is in same directory
data = pd.read_csv("/Users/yanivbronshtein/Downloads/adult.data")  # type and enter pwd and see if dataset is in same directory

#renaming columns
new_names =["age","workclass","fnlwgt","education","education.num","marital.status","occupation","relationship","race","sex","capital.gain","capital.loss","hours.per.week","native.country","salary"]


data = data.rename(columns={i:j for i,j in zip(data.columns,new_names)})


data[20:30]
# Out:
#     age     workclass  fnlwgt      education  education.num  \
# 20   54       Private  302146        HS-grad              9
# 21   35   Federal-gov   76845            9th              5
# 22   43       Private  117037           11th              7
# 23   59       Private  109015        HS-grad              9
# 24   56     Local-gov  216851      Bachelors             13
# 25   19       Private  168294        HS-grad              9
# 26   54             ?  180211   Some-college             10
# 27   39       Private  367260        HS-grad              9
# 28   49       Private  193366        HS-grad              9
# 29   23     Local-gov  190709     Assoc-acdm             12
#
#          marital.status         occupation    relationship  \
# 20            Separated      Other-service       Unmarried
# 21   Married-civ-spouse    Farming-fishing         Husband
# 22   Married-civ-spouse   Transport-moving         Husband
# 23             Divorced       Tech-support       Unmarried
# 24   Married-civ-spouse       Tech-support         Husband
# 25        Never-married       Craft-repair       Own-child
# 26   Married-civ-spouse                  ?         Husband
# 27             Divorced    Exec-managerial   Not-in-family
# 28   Married-civ-spouse       Craft-repair         Husband
# 29        Never-married    Protective-serv   Not-in-family
#
#                    race      sex  capital.gain  capital.loss  hours.per.week  \
# 20                Black   Female             0             0              20
# 21                Black     Male             0             0              40
# 22                White     Male             0          2042              40
# 23                White   Female             0             0              40
# 24                White     Male             0             0              40
# 25                White     Male             0             0              40
# 26   Asian-Pac-Islander     Male             0             0              60
# 27                White     Male             0             0              80
# 28                White     Male             0             0              40
# 29                White     Male             0             0              52
#
#     native.country  salary
# 20   United-States   <=50K
# 21   United-States   <=50K
# 22   United-States   <=50K
# 23   United-States   <=50K
# 24   United-States    >50K
# 25   United-States   <=50K
# 26           South    >50K
# 27   United-States   <=50K
# 28   United-States   <=50K
# 29   United-States   <=50K

# %%
data.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.shape # 299 rows, 13 cols
# Out:
# (32560, 15)

# %%
data.std()
# Out:
# age                   13.640642
# fnlwgt            105549.764924
# education.num          2.572709
# capital.gain        7385.402999
# capital.loss         402.966116
# hours.per.week        12.347618
# dtype: float64

# %%
data.info() # info about each variable
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
# age               32560 non-null int64
# workclass         32560 non-null object
# fnlwgt            32560 non-null int64
# education         32560 non-null object
# education.num     32560 non-null int64
# marital.status    32560 non-null object
# occupation        32560 non-null object
# relationship      32560 non-null object
# race              32560 non-null object
# sex               32560 non-null object
# capital.gain      32560 non-null int64
# capital.loss      32560 non-null int64
# hours.per.week    32560 non-null int64
# native.country    32560 non-null object
# salary            32560 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.isnull().any() # check if any missing data
# replace ? values with NaN
#print(data.loc[[26]]) getting data from row 26


val = data.at[26,'workclass']
for col in data:
    data[col]= data[col].replace([val],np.nan)
print(data.isnull().any()) 
data[20:40]
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education.num     False
# marital.status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital.gain      False
# capital.loss      False
# hours.per.week    False
# native.country     True
# salary            False
# dtype: bool
#     age          workclass  fnlwgt      education  education.num  \
# 20   54            Private  302146        HS-grad              9
# 21   35        Federal-gov   76845            9th              5
# 22   43            Private  117037           11th              7
# 23   59            Private  109015        HS-grad              9
# 24   56          Local-gov  216851      Bachelors             13
# 25   19            Private  168294        HS-grad              9
# 26   54                NaN  180211   Some-college             10
# 27   39            Private  367260        HS-grad              9
# 28   49            Private  193366        HS-grad              9
# 29   23          Local-gov  190709     Assoc-acdm             12
# 30   20            Private  266015   Some-college             10
# 31   45            Private  386940      Bachelors             13
# 32   30        Federal-gov   59951   Some-college             10
# 33   22          State-gov  311512   Some-college             10
# 34   48            Private  242406           11th              7
# 35   21            Private  197200   Some-college             10
# 36   19            Private  544091        HS-grad              9
# 37   31            Private   84154   Some-college             10
# 38   48   Self-emp-not-inc  265477     Assoc-acdm             12
# 39   31            Private  507875            9th              5
#
#          marital.status          occupation    relationship  \
# 20            Separated       Other-service       Unmarried
# 21   Married-civ-spouse     Farming-fishing         Husband
# 22   Married-civ-spouse    Transport-moving         Husband
# 23             Divorced        Tech-support       Unmarried
# 24   Married-civ-spouse        Tech-support         Husband
# 25        Never-married        Craft-repair       Own-child
# 26   Married-civ-spouse                 NaN         Husband
# 27             Divorced     Exec-managerial   Not-in-family
# 28   Married-civ-spouse        Craft-repair         Husband
# 29        Never-married     Protective-serv   Not-in-family
# 30        Never-married               Sales       Own-child
# 31             Divorced     Exec-managerial       Own-child
# 32   Married-civ-spouse        Adm-clerical       Own-child
# 33   Married-civ-spouse       Other-service         Husband
# 34        Never-married   Machine-op-inspct       Unmarried
# 35        Never-married   Machine-op-inspct       Own-child
# 36    Married-AF-spouse        Adm-clerical            Wife
# 37   Married-civ-spouse               Sales         Husband
# 38   Married-civ-spouse      Prof-specialty         Husband
# 39   Married-civ-spouse   Machine-op-inspct         Husband
#
#                    race      sex  capital.gain  capital.loss  hours.per.week  \
# 20                Black   Female             0             0              20
# 21                Black     Male             0             0              40
# 22                White     Male             0          2042              40
# 23                White   Female             0             0              40
# 24                White     Male             0             0              40
# 25                White     Male             0             0              40
# 26   Asian-Pac-Islander     Male             0             0              60
# 27                White     Male             0             0              80
# 28                White     Male             0             0              40
# 29                White     Male             0             0              52
# 30                Black     Male             0             0              44
# 31                White     Male             0          1408              40
# 32                White     Male             0             0              40
# 33                Black     Male             0             0              15
# 34                White     Male             0             0              40
# 35                White     Male             0             0              40
# 36                White   Female             0             0              25
# 37                White     Male             0             0              38
# 38                White     Male             0             0              40
# 39                White     Male             0             0              43
#
#     native.country  salary
# 20   United-States   <=50K
# 21   United-States   <=50K
# 22   United-States   <=50K
# 23   United-States   <=50K
# 24   United-States    >50K
# 25   United-States   <=50K
# 26           South    >50K
# 27   United-States   <=50K
# 28   United-States   <=50K
# 29   United-States   <=50K
# 30   United-States   <=50K
# 31   United-States   <=50K
# 32   United-States   <=50K
# 33   United-States   <=50K
# 34     Puerto-Rico   <=50K
# 35   United-States   <=50K
# 36   United-States   <=50K
# 37             NaN    >50K
# 38   United-States   <=50K
# 39   United-States   <=50K

# %%
#split dataframe w/ isna boolean operator on column workclass for imputation
#testing_workclass = data[data['workclass'].isin([np.nan])]
training_workclass = data.merge(testing_workclass, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='left_only']
training_workclass.head(3)
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
#
#         marital.status          occupation    relationship    race    sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
#
#    capital.gain  capital.loss  hours.per.week  native.country  salary  \
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
#
#       _merge
# 0  left_only
# 1  left_only
# 2  left_only

# %%
def create_categories_for_df(df):
    """
    df: Pandas dataframe
    returns nested dictionary {'col_name': {'val1': int, 'val2': int, 'val3': int}}
    Ex:
    {'marital.status':
     ' Married-civ-spouse': 14340,
     ' Never-married': 9916,
     ' Divorced': 4259,
     ' Separated': 959,
     ' Widowed': 840,
     ' Married-spouse-absent': 389,
     ' Married-AF-spouse': 21
     }
    """
    cols = data.columns.values.tolist()
    return_dict = {}
    for col in cols:
        return_dict[col] = dict(df[col].value_counts())
    return return_dict

# %%
my_dict = create_categories_for_df(training_workclass)

# %%
def get_categories_for_df_col(dict_of_dicts, col_name):
    """
    dict_of_dicts: dictionary containing column name for data frame and value list with frequencies
    col_name: string column name
    returns dictionary of frequencies
    """
    if col_name not in dict_of_dicts:
        print("The column", col_name, "does not exist in this nested dictionary")
        return None
    else:
        return dict_of_dicts[col_name]

# %%
get_categories_for_df_col(my_dict, 'marital.status')
# Out:
# {' Married-civ-spouse': 14340,
#  ' Never-married': 9916,
#  ' Divorced': 4259,
#  ' Separated': 959,
#  ' Widowed': 840,
#  ' Married-spouse-absent': 389,
#  ' Married-AF-spouse': 21}

# %%
print("Good job Jeff!")
# Out:
# Good job Jeff!

# %%
testing_workclass.head(3)
testing_workclass.describe()
# Out:
#                age         fnlwgt  education.num  capital.gain  capital.loss  \
# count  1836.000000    1836.000000    1836.000000   1836.000000   1836.000000
# mean     40.960240  188516.338235       9.260349    606.795752     60.760349
# std      20.334587  107089.902252       2.601986   5147.323872    354.685264
# min      17.000000   12285.000000       1.000000      0.000000      0.000000
# 25%      21.000000  117771.250000       9.000000      0.000000      0.000000
# 50%      35.000000  175617.000000       9.000000      0.000000      0.000000
# 75%      61.000000  234568.500000      10.000000      0.000000      0.000000
# max      90.000000  981628.000000      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count     1836.000000
# mean        31.919390
# std         14.909903
# min          1.000000
# 25%         20.000000
# 50%         36.000000
# 75%         40.000000
# max         99.000000

# %%
imputer = datawig.SimpleImputer(
    input_columns=[' age'], # column(s) containing information about the column we want to impute
    output_column= 'workclass', # the column we'd like to impute values for
    output_path = "imputer_model"
)
imputer = imputer.fit(train_df = training_workclass, test_df = testing_workclass)
#imputations = imputer.predict(testing_workclass)

#Impute missing values and return original dataframe with predictions
#imputed = imputer.predict(df_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' age'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-bf4727656ce5> in <module>
#       4     output_path = "imputer_model"
#       5 )
# ----> 6 imputer = imputer.fit(train_df = training_workclass, test_df = testing_workclass)
#       7 #imputations = imputer.predict(testing_workclass)
#       8
#
# ~/opt/anaconda3/lib/python3.7/site-packages/datawig/simple_imputer.py in fit(self, train_df, test_df, ctx, learning_rate, num_epochs, patience, test_split, weight_decay, batch_size, final_fc_hidden_units, calibrate, class_weights, instance_weights)
#     338         train_df = self.__add_weights_to_df(train_df, class_weights, instance_weights, in_place=False)
#     339
# --> 340         self.check_data_types(train_df)
#     341
#     342         data_encoders = []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/datawig/simple_imputer.py in check_data_types(self, data_frame)
#     134         :return:
#     135         """
# --> 136         self.numeric_columns = [c for c in self.input_columns if is_numeric_dtype(data_frame[c])]
#     137         self.string_columns = list(set(self.input_columns) - set(self.numeric_columns))
#     138         self.output_type = 'numeric' if is_numeric_dtype(data_frame[self.output_column]) else 'string'
#
# ~/opt/anaconda3/lib/python3.7/site-packages/datawig/simple_imputer.py in <listcomp>(.0)
#     134         :return:
#     135         """
# --> 136         self.numeric_columns = [c for c in self.input_columns if is_numeric_dtype(data_frame[c])]
#     137         self.string_columns = list(set(self.input_columns) - set(self.numeric_columns))
#     138         self.output_type = 'numeric' if is_numeric_dtype(data_frame[self.output_column]) else 'string'
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' age'

# %%
# df_train = training_workclass
# df_test = testing_workclass

# imputer = datawig.SimpleImputer(
#     input_columns=['age'], # column(s) containing information about the column we want to impute
#     output_column= 'workclass', # the column we'd like to impute values for
#     output_path = 'imputer_model' # stores model data and metrics
#     )
# imputer.fit(train_df=df_train, num_epochs=50)

# #Impute missing values and return original dataframe with predictions
# #imputed = imputer.predict(df_test)

# %%
#imputed = imputer.predict(data.loc[[26]])
#imputed.loc[[26]]

# %%
# Method 1 (doesnt work, refer to 2nd method below)

salary = {"<=50K": 0,">50K" : 1}   ### done to prepare for logit regression
data.salary = [salary[item] for item in data.salary]  # traversing through dataframe, matching key-value pairs
print(data)

# %%
# Method 2 (also doesnt work)
# Q: How to fix this?

# str(data.salary)
data.salary[data.salary == "<=50K"] = 0
data.salary[data.salary == ">50K"] = 1
data.head()

# %%
### NEW INFO ###
## Correlation matrix
data.corr()

# %%
var = "salary" # defining and checking descriptive stats of variable of interest
series = data[var]

# %%
print("Mean: {}".format(series.mean()))
print("Stdev: {}".format(series.std()))
print("Min: {}".format(series.min()))
print("Max: {}".format(series.max()))
print("Median: {}".format(series.median()))
print("Mode: {}".format(series.mode()))
print("Skew: {}".format(series.skew()))
print("Kurtosis: {}".format(series.kurtosis()))

# %%
### Graphical Summaries
## Scatterplots
sns.scatterplot(x = "age", y = "salary", data = data)

# %%
sns.scatterplot(x = "sex", y = "salary", data = data)

# %%
sns.scatterplot(x = "hours.per.week", y = "salary", data = data)

# %%
sns.scatterplot(x = "education.num", y = "salary", data = data) # used for testing continous DV
# Note: could also use just education, too, but then have to turn strings into binary

# %%
sns.pairplot(data = data)
# Q: How to zoom in on particular plots?

# %%
## Boxplots
sns.boxplot(x='sex', y='salary', data= data)

# %%
sns.boxplot(x='age', y='salary', data= data)

# %%
sns.boxplot(x='hours.per.week', y='salary', data= data)

# %%
# Get variable names

def getvar(x):
    for i in x:
        print(i)

# %%
getvar(data)

# %%
# Histograms
# Note: See cell 22 in Yaniv's EDA notebook

print(min(data['age']))
print(max(data['age'])) # used to check if increasing or decreasing bins is needed
data['age'].hist(bins=30)

# %%
print(min(data['fnlwgt']))
print(max(data['fnlwgt'])) # used to check if increasing or decreasing bins is needed
data['fnlwgt'].hist(bins=30)

# %%
print(min(data['education.num']))
print(max(data['education.num'])) # used to check if increasing or decreasing bins is needed
data['education.num'].hist(bins=30)

# %%
print(min(data['capital.gain']))
print(max(data['capital.gain'])) # used to check if increasing or decreasing bins is needed
data['capital.gain'].hist(bins=30)

# %%
print(min(data['capital.loss']))
print(max(data['capital.loss'])) # used to check if increasing or decreasing bins is needed
data['capital.loss'].hist(bins=30)

# %%
print(min(data['hours.per.week']))
print(max(data['hours.per.week'])) # used to check if increasing or decreasing bins is needed
data['hours.per.week'].hist(bins=30)

# %%
## Outliers (based on histograms... could also examine boxplots, if need be)
# Note: Can do it qualitatively or quantitatively... will be doing the former here. However, we can take the latter
# approach if we so desired: https://medium.com/datadriveninvestor/finding-outliers-in-dataset-using-python-efc3fce6ce32
# Q: Should use Judgement vs. IQR/Z-scores?

# Ex # 1: platelets variable
# Before
sns.scatterplot(x='	hours.per.week', y = 'salary', data=data)

# %%
# After
# See cell 32 in Yaniv's EDA notebook

data = data[data['hours.per.week'] <= 80]
sns.scatterplot(x='hours.per.week', y = 'salary', data=data)

# %%
# Ex #2: age variable
# Note: don't think we should exclude age, as study wanted to focus on all age groups, but just to see

# Before
sns.scatterplot(x='age', y = 'salary', data=data)

# %%
# After

data = data[data['age'] <= 80]
sns.scatterplot(x='age', y = 'salary', data=data)

# Q: Which variables to ultimately include in predictive models? Important to know since they may need to be adjusted for outliers

# %%
## Logistic Regression
## NOTE: As DEATH_EVENT is a binary variable, we must do logit; linear regression will not work
## Reference: https://gist.github.com/reenashaw/9de3608fa94f1a9ade0e19135afac70a

data['int']=1 #explicitly create a placeholder for y-intercept: b0
data.head()

# %%
IV = ['age','sex','hours.per.week']
model= sm.Logit(data['salary'], data[IV])
answer= model.fit()

# Note: MUST convert sex variable into binary 1st

# %%
answer.summary() #summarize the model
